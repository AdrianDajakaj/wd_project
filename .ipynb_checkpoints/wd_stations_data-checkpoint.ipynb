# %%
import pandas as pd
import requests
import time
import re
import unicodedata
import json

# %%
df_cities = pd.DataFrame(columns=['city'])

# %%
openaq_api_url = 'https://api.openaq.org/v2/'

# %%
endpoint = f"{openaq_api_url}/cities"
params = {
    "country": "PL",
    "limit": 10000,
}

response = requests.get(endpoint, params=params)

if response.status_code == 200:
    data = response.json()
    for result in data['results']:
        df_cities.loc[len(df_cities)] = [result['city']]
else:
    print(f"Failed to retrieve data: {response.status_code}")

# %%
df_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 197 entries, 0 to 196
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    197 non-null    object
# dtypes: object(1)
# memory usage: 3.1+ KB

# %%
def clean_city_name(city):
    return re.sub(r'^[^a-zA-ZąćęłńóśźżĄĆĘŁŃÓŚŹŻ]+', '', city).strip()

df_cities['city'] = df_cities['city'].apply(clean_city_name)

# %%
df_cities.head()
# Out:
#              city
# 0    Jelenia Góra
# 1        Augustów
# 2      Belsk Duży
# 3           Biała
# 4  Biała Podlaska

# %%
waqi_api_url = 'https://api.waqi.info'

# %%
waqi_api_token = '18d606fd3bbac19ab388244d380f3fe491ca2731'

# %%
def normalize_text(str_txt):
    return ''.join(c for c in unicodedata.normalize('NFKD', str_txt) if not unicodedata.combining(c))

def check_city_name(city, station):
    station_normalized = normalize_text(station)
    city_normalized = normalize_text(city)
    if '-' in city_normalized:
        station_normalized = station_normalized.replace('-', '')
        pattern = r'\b{}\b'.format(re.escape(city_normalized.replace('-','')))
        if re.search(pattern, station_normalized, re.IGNORECASE):
            return True
        else:
            return False
    elif ' ' in city_normalized:
        pattern = r'\b{}\b'.format(re.escape(city_normalized.replace(' ','')))
        if re.search(pattern, station_normalized.replace(' ',''), re.IGNORECASE):
            return True
        else:
            return False
    else:
        pattern = r'(?<!-)'+ re.escape(city_normalized) + r'(?=\s|-|$|,)'
        if re.search(pattern, station_normalized):
            return True
        else:
            return False

# %%
def search_stations(df, idx, city_name):
    print(f'Szukanie stacji dla miasta: {city_name}')
    url = waqi_api_url + f'/search/?token={waqi_api_token}&keyword={city_name}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        data = data['data']
        if(len(data) > 0):
            for elem in data:
                station_info = elem['station']
                if 'country' in station_info:
                    if station_info['country'] == 'PL':
                        station_name = station_info['name']
                        if station_name:
                            print(f'\tZnaleziono stację: {station_name}')
                            if check_city_name(city_name, station_name):
                                print(f'\tDodawanie stacji: {idx+1}')
                                uid = elem['uid']
                                lat = station_info['geo'][0]
                                lon = station_info['geo'][1]
                                station_url = station_info['url']
                                df.loc[idx] = [city_name, station_name, uid, lat, lon, station_url]
                                idx = idx+1
    return idx

# %%
stations_df = pd.DataFrame(columns=['city', 'station_name', 'station_id', 'station_lat', 'station_lon', 'station_url'])
stations_df_idx = 0

# %%
count = 0

# %%
for index, row in df_cities.iterrows():
        stations_df_idx = search_stations(stations_df, stations_df_idx, row['city'])
        count = count+1
        if (count) % 100 == 0:
            time.sleep(5)
# Out:
# Szukanie stacji dla miasta: Jelenia Góra
# 	Znaleziono stację: Jelenia Góra - Ogińskiego, Poland
# 	Dodawanie stacji: 1
# Szukanie stacji dla miasta: Augustów
# Szukanie stacji dla miasta: Belsk Duży
# Szukanie stacji dla miasta: Biała
# 	Znaleziono stację: Bielsko-Biała, ul. Partyzantów, Poland
# 	Znaleziono stację: Bielsko-Biała, ul. Kossak-Szczuckiej 19, Poland
# Szukanie stacji dla miasta: Biała Podlaska
# 	Znaleziono stację: Biała Podlaska, Poland
# 	Dodawanie stacji: 2
# Szukanie stacji dla miasta: Białystok
# 	Znaleziono stację: Białystok-Miejska, Poland
# 	Dodawanie stacji: 3
# Szukanie stacji dla miasta: Bielsko-Biała
# 	Znaleziono stację: Bielsko-Biała, ul. Partyzantów, Poland
# 	Dodawanie stacji: 4
# 	Znaleziono stację: Bielsko-Biała, ul. Kossak-Szczuckiej 19, Poland
# 	Dodawanie stacji: 5
# Szukanie stacji dla miasta: Boguchwała
# Szukanie stacji dla miasta: Borówiec
# Szukanie stacji dla miasta: Borsukowizna
# Szukanie stacji dla miasta: Brzeg
# Szukanie stacji dla miasta: Bydgoszcz
# 	Znaleziono stację: Bydgoszcz-Warszawska, Poland
# 	Dodawanie stacji: 6
# 	Znaleziono stację: airp. Bydgoszcz mobil, Poland
# 	Dodawanie stacji: 7
# 	Znaleziono stację: Bydgoszcz-Pl. Poznański, Poland
# 	Dodawanie stacji: 8
# Szukanie stacji dla miasta: Bytów
# Szukanie stacji dla miasta: Chełm
# Szukanie stacji dla miasta: Chojnice
# Szukanie stacji dla miasta: Chojnów
# Szukanie stacji dla miasta: Ciechocinek
# Szukanie stacji dla miasta: Cieszyn
# 	Znaleziono stację: Cieszyn, ul. Mickiewicza 13, Poland
# 	Dodawanie stacji: 9
# Szukanie stacji dla miasta: Czerniawa
# Szukanie stacji dla miasta: Czerwionka-Leszczyny
# Szukanie stacji dla miasta: Częstochowa
# 	Znaleziono stację: Częstochowa, ul. Baczyńskiego 2, Poland
# 	Dodawanie stacji: 10
# 	Znaleziono stację: Częstochowa, Al. Armii Krajowej 3 (komunikacyjna), Poland
# 	Dodawanie stacji: 11
# Szukanie stacji dla miasta: Dąbki
# Szukanie stacji dla miasta: Dąbrowa Górnicza
# 	Znaleziono stację: Dąbrowa Górnicza, ul. Tysiąclecia 25a, Poland
# 	Dodawanie stacji: 12
# 	Znaleziono stację: Sosnowiec, ul. Lubelska 51, Poland
# Szukanie stacji dla miasta: Dębica
# 	Znaleziono stację: Dębica-Grottgera-WIOS, Poland
# 	Dodawanie stacji: 13
# Szukanie stacji dla miasta: Diabla Góra
# Szukanie stacji dla miasta: Działdowo
# Szukanie stacji dla miasta: Działoszyn
# Szukanie stacji dla miasta: Dzierżoniów
# 	Znaleziono stację: Dzierżoniów - Piłsudskiego, Poland
# 	Dodawanie stacji: 14
# Szukanie stacji dla miasta: Elbląg
# Szukanie stacji dla miasta: Ełk
# Szukanie stacji dla miasta: Florianka
# Szukanie stacji dla miasta: Gajew
# Szukanie stacji dla miasta: Gdańsk
# 	Znaleziono stację: Gdansk Srodmiescie, Gdansk, Poland
# 	Dodawanie stacji: 15
# 	Znaleziono stację: Gdansk Stogi, Gdansk, Poland
# 	Dodawanie stacji: 16
# 	Znaleziono stację: Gdansk Wrzeszcz, Gdansk, Poland
# 	Dodawanie stacji: 17
# 	Znaleziono stację: Gdansk Nowy Port, Gdansk, Poland
# 	Dodawanie stacji: 18
# 	Znaleziono stację: gdansko starogardas; Starogard Gdański, Poland
# Szukanie stacji dla miasta: Gdynia
# 	Znaleziono stację: Gdynia Pogorze, Gdansk, Poland
# 	Dodawanie stacji: 19
# 	Znaleziono stację: Gdynia Dabrowa, Gdansk, Poland
# 	Dodawanie stacji: 20
# 	Znaleziono stację: Gdynia Srodmiescie, Gdansk, Poland
# 	Dodawanie stacji: 21
# Szukanie stacji dla miasta: Gliwice
# 	Znaleziono stację: Gliwice, ul. Mewy 34, Poland
# 	Dodawanie stacji: 22
# Szukanie stacji dla miasta: Głubczyce
# Szukanie stacji dla miasta: Goczałkowice-Zdrój
# Szukanie stacji dla miasta: Gołdap
# Szukanie stacji dla miasta: Gołuchów
# Szukanie stacji dla miasta: Gorzów Wielkopolski
# 	Znaleziono stację: Gorzów Wielkopolski, Poland
# 	Dodawanie stacji: 23
# Szukanie stacji dla miasta: Grajewo
# Szukanie stacji dla miasta: Granica
# Szukanie stacji dla miasta: Grudziądz
# 	Znaleziono stację: airp. Grudziądz, Poland
# 	Dodawanie stacji: 24
# Szukanie stacji dla miasta: Guty Duże
# Szukanie stacji dla miasta: Inowrocław
# 	Znaleziono stację: airp. Inowrocław, Poland
# 	Dodawanie stacji: 25
# Szukanie stacji dla miasta: Janów Lubelski
# Szukanie stacji dla miasta: Jarczew
# Szukanie stacji dla miasta: Jarosław
# 	Znaleziono stację: Jarosław-PWSTE-WIOS, Poland
# 	Dodawanie stacji: 26
# Szukanie stacji dla miasta: Jasło
# 	Znaleziono stację: Jasło ul. Sikorskiego, Poland
# 	Dodawanie stacji: 27
# Szukanie stacji dla miasta: Jastrzębie-Zdrój
# 	Znaleziono stację: jastrzebie-zdroj; Jastrzębie-Zdrój, Aleja Józefa Piłsudskiego (Harcerska 3), Poland
# 	Dodawanie stacji: 28
# Szukanie stacji dla miasta: Jedlicze
# Szukanie stacji dla miasta: Jedlina-Zdrój
# Szukanie stacji dla miasta: Kalisz
# 	Znaleziono stację: Kalisz ul.Hanki Sawickiej, Poland
# 	Dodawanie stacji: 29
# Szukanie stacji dla miasta: Kamień Pomorski
# Szukanie stacji dla miasta: Karpacz
# Szukanie stacji dla miasta: Kaszów
# Szukanie stacji dla miasta: Katowice
# 	Znaleziono stację: Katowice, ul Kossutha 6, Poland
# 	Dodawanie stacji: 30
# Szukanie stacji dla miasta: Kazimierza Wielka
# Szukanie stacji dla miasta: Kędzierzyn-Koźle
# 	Znaleziono stację: K-Koźle, Poland
# Szukanie stacji dla miasta: Kętrzyn
# Szukanie stacji dla miasta: Kielce
# 	Znaleziono stację: Kielce, ul. Targowa 3, Poland
# 	Dodawanie stacji: 31
# 	Znaleziono stację: Kielce ul. Jagiellońska, Poland
# 	Dodawanie stacji: 32
# Szukanie stacji dla miasta: Kłodzko
# 	Znaleziono stację: Kłodzko - Szkolna, Poland
# 	Dodawanie stacji: 33
# Szukanie stacji dla miasta: Kołobrzeg
# Szukanie stacji dla miasta: Koniczynka
# Szukanie stacji dla miasta: Konin
# 	Znaleziono stację: Konin ul. Wyszyńskiego, Poland
# 	Dodawanie stacji: 34
# Szukanie stacji dla miasta: Konstancin-Jeziorna
# 	Znaleziono stację: Wierzejewskiego, Konstancin-Jeziorna, Mazowieckie, Poland
# 	Dodawanie stacji: 35
# 	Znaleziono stację: Jeziorna, Konstancin, Mazowieckie, Poland
# Szukanie stacji dla miasta: Kościan
# Szukanie stacji dla miasta: Kościerzyna
# 	Znaleziono stację: Kościerzyna, Poland
# 	Dodawanie stacji: 36
# Szukanie stacji dla miasta: Koszalin
# 	Znaleziono stację: Koszalin ul. Armii Krajowej, Poland
# 	Dodawanie stacji: 37
# Szukanie stacji dla miasta: Koziegłowy
# Szukanie stacji dla miasta: Kraków
# 	Znaleziono stację: Aleja Krasińskiego, Kraków, Małopolska, Poland
# 	Dodawanie stacji: 38
# 	Znaleziono stację: Kraków, ul. Złoty Róg, Małopolska, Poland
# 	Dodawanie stacji: 39
# 	Znaleziono stację: Kurdwanów, Kraków, Małopolska, Poland
# 	Dodawanie stacji: 40
# 	Znaleziono stację: Kraków, os. Piastów, Małopolska, Poland
# 	Dodawanie stacji: 41
# 	Znaleziono stację: Kraków, os. Swoszowice, Małopolska, Poland
# 	Dodawanie stacji: 42
# 	Znaleziono stację: Kraków-ul. Dietla, Małopolska, Poland
# 	Dodawanie stacji: 43
# 	Znaleziono stację: Kraków, ul. Telimeny, Małopolska, Poland
# 	Dodawanie stacji: 44
# 	Znaleziono stację: biala krakowska; Bielsko-Biała, ul. Partyzantów, Poland
# 	Znaleziono stację: biala krakowska; Bielsko-Biała, ul. Kossak-Szczuckiej 19, Poland
# Szukanie stacji dla miasta: Krapkowice
# Szukanie stacji dla miasta: Krempna
# Szukanie stacji dla miasta: Krosno
# 	Znaleziono stację: Krosno-Kletówki-WIOS, Poland
# 	Dodawanie stacji: 45
# Szukanie stacji dla miasta: Krzyżówka
# Szukanie stacji dla miasta: Kudowa-Zdrój
# Szukanie stacji dla miasta: Kutno
# Szukanie stacji dla miasta: Łagów
# Szukanie stacji dla miasta: Łask
# Szukanie stacji dla miasta: Łeba
# Szukanie stacji dla miasta: Lębork
# 	Znaleziono stację: Lębork, Poland
# 	Dodawanie stacji: 46
# Szukanie stacji dla miasta: Legionowo
# 	Znaleziono stację: Zegrzyńska, Legionowo, Mazowieckie, Poland
# 	Dodawanie stacji: 47
# Szukanie stacji dla miasta: Legnica
# 	Znaleziono stację: Legnica - Rzeczypospolitej, Poland
# 	Dodawanie stacji: 48
# Szukanie stacji dla miasta: Liniewko Kościerskie
# Szukanie stacji dla miasta: Łódź
# 	Znaleziono stację: Łódź-Gdańska 16, Poland
# 	Dodawanie stacji: 49
# 	Znaleziono stację: Łódź-Jana Pawła II 15, Poland
# 	Dodawanie stacji: 50
# 	Znaleziono stację: Łódź, ul. Zachodnia 40, Poland
# 	Dodawanie stacji: 51
# 	Znaleziono stację: Łódź-Kilińskiego komunikacyjna, Poland
# 	Dodawanie stacji: 52
# 	Znaleziono stację: Pabianice, ul. Konstantynowska, Poland
# Szukanie stacji dla miasta: Łomża
# 	Znaleziono stację: Łomża-Miejska, Poland
# 	Dodawanie stacji: 53
# Szukanie stacji dla miasta: Lublin
# 	Znaleziono stację: Lublin ul.Obywatelska, Poland
# 	Dodawanie stacji: 54
# 	Znaleziono stację: Lubliniec, ul. Ks. Szymały, Poland
# Szukanie stacji dla miasta: Lubliniec
# 	Znaleziono stację: Lubliniec, ul. Ks. Szymały, Poland
# 	Dodawanie stacji: 55
# Szukanie stacji dla miasta: Lubsko
# Szukanie stacji dla miasta: Łuków
# Szukanie stacji dla miasta: Lwówek Śląski
# Szukanie stacji dla miasta: Malbork
# 	Znaleziono stację: Malbork, Poland
# 	Dodawanie stacji: 56
# Szukanie stacji dla miasta: Małogoszcz
# Szukanie stacji dla miasta: Międzyrzecz
# Szukanie stacji dla miasta: Mielec
# 	Znaleziono stację: Mielec-Biernackiego-WIOS, Poland
# 	Dodawanie stacji: 57
# 	Znaleziono stację: Mielec-MOSIR-WIOS, Poland
# 	Dodawanie stacji: 58
# Szukanie stacji dla miasta: Mosina
# Szukanie stacji dla miasta: Muszyna
# Szukanie stacji dla miasta: Myślenice
# Szukanie stacji dla miasta: Nakło nad Notecią
# Szukanie stacji dla miasta: Niepołomice
# Szukanie stacji dla miasta: Nisko
# 	Znaleziono stację: Nisko ul. Szklarniowa, Poland
# 	Dodawanie stacji: 59
# Szukanie stacji dla miasta: Nowa Ruda
# 	Znaleziono stację: Nowa Ruda - Jeziorna, Poland
# 	Dodawanie stacji: 60
# 	Znaleziono stację: Nowa Ruda - Srebrna, Poland
# 	Dodawanie stacji: 61
# Szukanie stacji dla miasta: Nowa Sól
# Szukanie stacji dla miasta: Nowiny
# Szukanie stacji dla miasta: Nowy Sącz
# 	Znaleziono stację: Nowy Sącz, Małopolska, Poland
# 	Dodawanie stacji: 62
# Szukanie stacji dla miasta: Nowy Targ
# 	Znaleziono stację: Nowy Targ, Pl. Słowackiego, Małopolska, Poland
# 	Dodawanie stacji: 63
# Szukanie stacji dla miasta: Nysa
# 	Znaleziono stację: Nysa, ul. Rodziewiczówny, Poland
# 	Dodawanie stacji: 64
# 	Znaleziono stację: lgnytsa; Legnica - Rzeczypospolitej, Poland
# Szukanie stacji dla miasta: Oława
# 	Znaleziono stację: Oława - Żołnierzy AK, Poland
# 	Dodawanie stacji: 65
# Szukanie stacji dla miasta: Olesno
# Szukanie stacji dla miasta: Olkusz
# 	Znaleziono stację: Olkusz,  Cegielniana, Krakow, Poland
# 	Dodawanie stacji: 66
# 	Znaleziono stację: Olkusz, Małopolska, Poland
# 	Dodawanie stacji: 67
# Szukanie stacji dla miasta: Olsztyn
# Szukanie stacji dla miasta: Opole
# 	Znaleziono stację: Opole, ul. Koszyka 21, Poland
# 	Dodawanie stacji: 68
# 	Znaleziono stację: Opole, Poland
# 	Dodawanie stacji: 69
# 	Znaleziono stację: opoles stselces; Strzelce Opolskie, ul.Kardynała Wyszyńskiego, Poland
# Szukanie stacji dla miasta: Osieczów
# Szukanie stacji dla miasta: Ostróda
# Szukanie stacji dla miasta: Oświęcim
# 	Znaleziono stację: Oświęcim, ul. J. Bema, Małopolska, Poland
# 	Dodawanie stacji: 70
# Szukanie stacji dla miasta: Otwock
# 	Znaleziono stację: Brzozowa, Otwock, Mazowieckie, Poland
# 	Dodawanie stacji: 71
# Szukanie stacji dla miasta: Pabianice
# 	Znaleziono stację: Pabianice, ul. Konstantynowska, Poland
# 	Dodawanie stacji: 72
# Szukanie stacji dla miasta: Parzniewice
# Szukanie stacji dla miasta: Piastów
# 	Znaleziono stację: Pułaskiego, Piastów, Mazowieckie, Poland
# 	Dodawanie stacji: 73
# Szukanie stacji dla miasta: Piła
# 	Znaleziono stację: Piła ul. Kusocińskiego, Poland
# 	Dodawanie stacji: 74
# Szukanie stacji dla miasta: Pińczów
# Szukanie stacji dla miasta: Piotrków Trybunalski
# 	Znaleziono stację: Piotrków, ul. Krakowskie Przedmieście 13, Poland
# Szukanie stacji dla miasta: Pleszew
# Szukanie stacji dla miasta: Płock
# 	Znaleziono stację: Gimnazjum, Płock, Mazowieckie, Poland
# 	Dodawanie stacji: 75
# 	Znaleziono stację: Reja, Płock, Mazowieckie, Poland
# 	Dodawanie stacji: 76
# Szukanie stacji dla miasta: Polanica-Zdrój
# Szukanie stacji dla miasta: Połaniec
# Szukanie stacji dla miasta: Poznań
# 	Znaleziono stację: Poznań 2 Ogród Botaniczny, Poland
# 	Dodawanie stacji: 77
# 	Znaleziono stację: Poznań 1 ul. Polanka, Poland
# 	Dodawanie stacji: 78
# 	Znaleziono stację: Koziegłowy-os.Leśne, Poland
# 	Znaleziono stację: 9.Poznań-Żelazna, Poland
# 	Dodawanie stacji: 79
# Szukanie stacji dla miasta: Przemyśl
# 	Znaleziono stację: Przemyśl ul. Grunwaldzka, Poland
# 	Dodawanie stacji: 80
# Szukanie stacji dla miasta: Pułtusk
# Szukanie stacji dla miasta: Rabka-Zdrój
# Szukanie stacji dla miasta: Racibórz
# 	Znaleziono stację: Stacja mobilna Racibórz, ul. Wojska Polskiego, Poland
# 	Dodawanie stacji: 81
# Szukanie stacji dla miasta: Radom
# 	Znaleziono stację: Tochtermana, Radom, Mazowieckie, Poland
# 	Dodawanie stacji: 82
# Szukanie stacji dla miasta: Radomsko
# Szukanie stacji dla miasta: Radzyń Podlaski
# Szukanie stacji dla miasta: Rudnik nad Sanem
# Szukanie stacji dla miasta: Rybnik
# 	Znaleziono stację: Rybnik, ul. Borki 37a, Poland
# 	Dodawanie stacji: 83
# Szukanie stacji dla miasta: Rymanów-Zdrój
# Szukanie stacji dla miasta: Rzeszów
# 	Znaleziono stację: Rzeszów-Piłsudskiego-WIOS, Poland
# 	Dodawanie stacji: 84
# 	Znaleziono stację: Rzeszów ul. Rejtana, Poland
# 	Dodawanie stacji: 85
# Szukanie stacji dla miasta: Sanok
# Szukanie stacji dla miasta: Siedlce
# 	Znaleziono stację: Konarskiego, Siedlce, Mazowieckie, Poland
# 	Dodawanie stacji: 86
# Szukanie stacji dla miasta: Sierpc
# Szukanie stacji dla miasta: Skarżysko-Kamienna
# Szukanie stacji dla miasta: Skawina
# 	Znaleziono stację: Skawina, Małopolska, Poland
# 	Dodawanie stacji: 87
# Szukanie stacji dla miasta: Słupsk
# 	Znaleziono stację: Słupsk, Poland
# 	Dodawanie stacji: 88
# Szukanie stacji dla miasta: Smolary Bytnickie
# Szukanie stacji dla miasta: Solec Kujawski
# Szukanie stacji dla miasta: Sopot
# 	Znaleziono stację: Sopot, Gdansk, Poland
# 	Dodawanie stacji: 89
# 	Znaleziono stację: Gdansk Wrzeszcz, Gdansk, Poland
# 	Znaleziono stację: Gdynia Srodmiescie, Gdansk, Poland
# Szukanie stacji dla miasta: Sosnowiec
# 	Znaleziono stację: Sosnowiec, ul. Lubelska 51, Poland
# 	Dodawanie stacji: 90
# Szukanie stacji dla miasta: Starachowice
# 	Znaleziono stację: Starachowice, ul. Złota, Poland
# 	Dodawanie stacji: 91
# Szukanie stacji dla miasta: Strzegom
# Szukanie stacji dla miasta: Strzelce Opolskie
# 	Znaleziono stację: Strzelce Opolskie, ul.Kardynała Wyszyńskiego, Poland
# 	Dodawanie stacji: 92
# Szukanie stacji dla miasta: Sucha Beskidzka
# Szukanie stacji dla miasta: Sulęcin
# Szukanie stacji dla miasta: Suwałki
# 	Znaleziono stację: Suwałki ul. Pułaskiego, Poland
# 	Dodawanie stacji: 93
# 	Znaleziono stację: Suwałki-Miejska, Poland
# 	Dodawanie stacji: 94
# Szukanie stacji dla miasta: Świecie
# Szukanie stacji dla miasta: Szamotuły
# Szukanie stacji dla miasta: Szarów
# Szukanie stacji dla miasta: Szczawnica
# Szukanie stacji dla miasta: Szczecin
# 	Znaleziono stację: Szczecin ul. Piłsudskiego, Poland
# 	Dodawanie stacji: 95
# 	Znaleziono stację: Szczecin ul. Łączna, Poland
# 	Dodawanie stacji: 96
# 	Znaleziono stację: Szczecinek ul. Przemysłowa, Poland
# Szukanie stacji dla miasta: Szczecinek
# 	Znaleziono stację: Szczecinek ul. Przemysłowa, Poland
# 	Dodawanie stacji: 97
# Szukanie stacji dla miasta: Szczytno
# Szukanie stacji dla miasta: Szymbark
# Szukanie stacji dla miasta: Tarnobrzeg
# Szukanie stacji dla miasta: Tarnów
# 	Znaleziono stację: Tarnów, Małopolska, Poland
# 	Dodawanie stacji: 98
# 	Znaleziono stację: Tarnów-ul. Ks. Romana Sitko, Małopolska, Poland
# 	Dodawanie stacji: 99
# Szukanie stacji dla miasta: Toruń
# 	Znaleziono stację: airp. Toruń, Poland
# 	Dodawanie stacji: 100
# 	Znaleziono stację: Toruń-Kaszownik, Poland
# 	Dodawanie stacji: 101
# 	Znaleziono stację: Toruń-Policja, Poland
# 	Dodawanie stacji: 102
# Szukanie stacji dla miasta: Trzebinia
# 	Znaleziono stację: Trzebinia, Małopolska, Poland
# 	Dodawanie stacji: 103
# Szukanie stacji dla miasta: Trzebnica
# Szukanie stacji dla miasta: Tychy
# 	Znaleziono stację: Tychy, ul. Tołstoja 1, Poland
# 	Dodawanie stacji: 104
# Szukanie stacji dla miasta: Uście Gorlickie Wysowa
# Szukanie stacji dla miasta: Ustka
# Szukanie stacji dla miasta: Ustroń
# 	Znaleziono stację: Ustroń, Sanatoryjna 7, Poland
# 	Dodawanie stacji: 105
# Szukanie stacji dla miasta: Wadowice
# Szukanie stacji dla miasta: Wałbrzych
# 	Znaleziono stację: Wałbrzych - Wysockiego, Poland
# 	Dodawanie stacji: 106
# Szukanie stacji dla miasta: Warszawa
# 	Znaleziono stację: Marszałkowska, Warszawa, Mazowieckie, Poland
# 	Dodawanie stacji: 107
# 	Znaleziono stację: Ursynów, Warszawa, Mazowieckie, Poland
# 	Dodawanie stacji: 108
# 	Znaleziono stację: Targówek, Warszawa, Mazowieckie, Poland
# 	Dodawanie stacji: 109
# 	Znaleziono stację: Komunikacyjna, Warszawa, Mazowieckie, Poland
# 	Dodawanie stacji: 110
# 	Znaleziono stację: warszawa-ursus; Pułaskiego, Piastów, Mazowieckie, Poland
# Szukanie stacji dla miasta: Widuchowa
# Szukanie stacji dla miasta: Wilczopole
# Szukanie stacji dla miasta: Włocławek
# 	Znaleziono stację: Włocławek-Okrzei, Poland
# 	Dodawanie stacji: 111
# Szukanie stacji dla miasta: Włoszczowa
# Szukanie stacji dla miasta: Wodzisław Śląski
# 	Znaleziono stację: Wodzisław, Gałczyńskiego 1, Poland
# Szukanie stacji dla miasta: Wrocław
# 	Znaleziono stację: Wrocław - Korzeniowskiego, Poland
# 	Dodawanie stacji: 112
# 	Znaleziono stację: Wrocław - Wiśniowa, Poland
# 	Dodawanie stacji: 113
# Szukanie stacji dla miasta: Wschowa
# Szukanie stacji dla miasta: Zabierzów
# Szukanie stacji dla miasta: Zabrze
# 	Znaleziono stację: Zabrze, ul. Skłodowskiej-Curie 34, Poland
# 	Dodawanie stacji: 114
# Szukanie stacji dla miasta: Żagań
# Szukanie stacji dla miasta: Zakopane
# 	Znaleziono stację: Zakopane, Małopolska, Poland
# 	Dodawanie stacji: 115
# Szukanie stacji dla miasta: Zamość
# 	Znaleziono stację: Zamość, Poland
# 	Dodawanie stacji: 116
# Szukanie stacji dla miasta: Żary
# 	Znaleziono stację: Żary, Poland
# 	Dodawanie stacji: 117
# Szukanie stacji dla miasta: Zawiercie
# 	Znaleziono stację: Zawiercie, ul. Gałczyńskiego, Poland
# 	Dodawanie stacji: 118
# Szukanie stacji dla miasta: Zdzieszowice
# Szukanie stacji dla miasta: Zgierz
# 	Znaleziono stację: Zgierz, ul. Mielczarskiego 1, Poland
# 	Dodawanie stacji: 119
# 	Znaleziono stację: Łódź-Gdańska 16, Poland
# 	Znaleziono stację: Łódź, ul. Zachodnia 40, Poland
# Szukanie stacji dla miasta: Zgorzelec
# Szukanie stacji dla miasta: Zielona Góra
# 	Znaleziono stację: Zielona Góra, Poland
# 	Dodawanie stacji: 120
# Szukanie stacji dla miasta: Zielonka
# Szukanie stacji dla miasta: Złoty Potok
# Szukanie stacji dla miasta: Żory
# Szukanie stacji dla miasta: Żyrardów
# 	Znaleziono stację: Roosevelta, Żyrardów, Mazowieckie, Poland
# 	Dodawanie stacji: 121
# Szukanie stacji dla miasta: Żywiec
# 	Znaleziono stację: Żywiec, ul. Kopernika 84, Poland
# 	Dodawanie stacji: 122
# 	Znaleziono stację: Żywiec, ul. Słowackiego 2, Poland
# 	Dodawanie stacji: 123

# %%
stations_df.head()
# Out:
#              city                                     station_name  \
# 0    Jelenia Góra                Jelenia Góra - Ogińskiego, Poland
# 1  Biała Podlaska                           Biała Podlaska, Poland
# 2       Białystok                        Białystok-Miejska, Poland
# 3   Bielsko-Biała           Bielsko-Biała, ul. Partyzantów, Poland
# 4   Bielsko-Biała  Bielsko-Biała, ul. Kossak-Szczuckiej 19, Poland
#
#    station_id  station_lat  station_lon  \
# 0        8135    50.913470    15.765659
# 1        6479    52.038713    23.144503
# 2        6520    53.126815    23.156370
# 3       10544    49.802089    19.048629
# 4        6535    49.813464    19.027318
#
#                                          station_url
# 0        poland/dolnoslaskie/jelenia-gora-oginskiego
# 1                       poland/lublin/biala-podlaska
# 2                 poland/bialystok/bialystok-miejska
# 3       poland/slaski/bielsko-biala--ul.-partyzantow
# 4  poland/slaski/bielsko-biala--ul.-kossak-szczuc...

# %%
stations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, 0 to 122
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          123 non-null    object
#  1   station_name  123 non-null    object
#  2   station_id    123 non-null    int64
#  3   station_lat   123 non-null    float64
#  4   station_lon   123 non-null    float64
#  5   station_url   123 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 6.7+ KB

# %%
unique_cities = pd.DataFrame({'city': stations_df['city'].unique()})

# %%
unique_cities.to_csv('collected_data/cities_list.csv', index=False)

# %%
csv_file_path = 'stations_info.csv'
stations_df.to_csv(f'collected_data/{csv_file_path}', index=False)
